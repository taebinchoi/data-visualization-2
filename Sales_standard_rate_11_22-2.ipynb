# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
years = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
data = {
    'EUR': [1541.66, 1447.58, 1453.47, 1398.81, 1255.78, 1284.10, 1276.44, 1299.65, 1305.86, 1346.11, 1353.40, 1359.46],
    'USD': [1108.09, 1126.43, 1094.97, 1053.30, 1132.10, 1161.11, 1130.61, 1101.08, 1166.51, 1179.90, 1145.07, 1293.68],
    'GBP': [1775.71, 1784.59, 1711.43, 1734.65, 1730.56, 1572.80, 1455.29, 1469.19, 1488.50, 1513.26, 1574.82, 1594.39],
    'JPY (100Y)': [1391.86, 1412.96, 1123.73, 996.37, 935.06, 1069.31, 1008.29, 997.07, 1070.63, 1105.36, 1041.92, 985.24],
    'CAD': [1120.36, 1127.02, 1063.13, 953.56, 885.61, 876.60, 871.61, 849.50, 879.19, 880.04, 913.68, 993.00],
    'CNY': [171.51, 178.52, 178.11, 170.95, 179.52, 174.43, 167.47, 166.48, 168.68, 170.90, 177.56, 191.73]
}

plt.figure(figsize=(12, 6))

for currency, values in data.items():
    plt.plot(years, values, label=currency, marker='o')

plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Sales standard rate')

plt.legend()
plt.grid(True)
plt.show()
