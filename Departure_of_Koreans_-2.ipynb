# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
years = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
travelers = [1484.6, 1608.1, 1931.0, 2238.3, 2649.6, 2869.6, 2871.4, 427.6, 122.3, 655.4]

plt.plot(years, travelers, color='brown', label='Departure of Koreans (10,000)', marker='o', linestyle='--')
plt.xlabel('Year')
plt.ylabel('Travelers (10,000)')
plt.title('Departure of Koreans')
plt.legend()
plt.show()
