# %%
import pandas as pd
import numpy as np

# %%
# !pip install koreanize-matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 61.9 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
worldtour = pd.read_excel('World tourism data 11-20.xlsx')
worldtour
# Out:
#      Nations     2011 Unnamed: 2   2011.1     2012 Unnamed: 5   2012.1  \
# 0        국가별  Revenue   Spending  Balance  Revenue   Spending  Balance
# 1      Korea    12500      19900    -7400    13400      20600    -7200
# 2      China    48500      72600   -24100    50000     102000   -52000
# 3        USA   115600      78200    37400   161200     100300    60900
# 4      Japan    11000      27200   -16200    14600      27900   -13300
# 5  Hong Kong    28500      19000     9500    33100      20100    13000
# 6     Taiwan    11100      10100     1000    11800      10600     1200
#
#       2013 Unnamed: 8   2013.1  ...   2017.1     2018 Unnamed: 23   2018.1  \
# 0  Revenue   Spending  Balance  ...  Balance  Revenue    Spending  Balance
# 1    14600      21600    -7000  ...   -18300    18600       35100   -16500
# 2    51700     128600   -76900  ...  -219300    40400      277300  -236900
# 3   172900     104100    68800  ...    75700   196500      126000    70500
# ...

# %%
worldtour.rename(columns={worldtour.columns[1] : '11re',
                           worldtour.columns[2] : '11sp',
                           worldtour.columns[3] : '2011',
                           worldtour.columns[4] : '12re',
                           worldtour.columns[5] : '12sp',
                           worldtour.columns[6] : '2012',
                           worldtour.columns[7] : '13re',
                           worldtour.columns[8] : '13sp',
                           worldtour.columns[9] : '2013',
                           worldtour.columns[10] : '14re',
                           worldtour.columns[11] : '14sp',
                           worldtour.columns[12] : '2014',
                           worldtour.columns[13] : '15re',
                           worldtour.columns[14] : '15sp',
                           worldtour.columns[15] : '2015',
                           worldtour.columns[16] : '16re',
                           worldtour.columns[17] : '16sp',
                           worldtour.columns[18] : '2016',
                           worldtour.columns[19] : '17re',
                           worldtour.columns[20] : '17sp',
                           worldtour.columns[21] : '2017',
                           worldtour.columns[22] : '18re',
                           worldtour.columns[23] : '18sp',
                           worldtour.columns[24] : '2018',
                           worldtour.columns[25] : '19re',
                           worldtour.columns[26] : '19sp',
                           worldtour.columns[27] : '2019',
                           worldtour.columns[28] : '20re',
                           worldtour.columns[29] : '20sp',
                           worldtour.columns[30] : '2020'},
                  inplace=True)
worldtour
# Out:
#      Nations     11re      11sp     2011     12re      12sp     2012     13re  \
# 0        국가별  Revenue  Spending  Balance  Revenue  Spending  Balance  Revenue
# 1      Korea    12500     19900    -7400    13400     20600    -7200    14600
# 2      China    48500     72600   -24100    50000    102000   -52000    51700
# 3        USA   115600     78200    37400   161200    100300    60900   172900
# 4      Japan    11000     27200   -16200    14600     27900   -13300    15100
# 5  Hong Kong    28500     19000     9500    33100     20100    13000    38900
# 6     Taiwan    11100     10100     1000    11800     10600     1200    12300
#
#        13sp     2013  ...     2017     18re      18sp     2018     19re  \
# 0  Spending  Balance  ...  Balance  Revenue  Spending  Balance  Revenue
# 1     21600    -7000  ...   -18300    18600     35100   -16500    20900
# 2    128600   -76900  ...  -219300    40400    277300  -236900    35800
# ...
